# %% [markdown]
# # Practica redes convolucionales : Clasificación de flores
#
# ___
#
# Sergio David Díaz Veru
#
# En la siguiente guía aplicaran los conceptos de redes convolucionales para realizar la clasificación de imágenes de flores. Experimente.

# %% [markdown]
# ## Importe de librerias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import r2_score
from datetime import datetime, timedelta
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## Carga de Datos de la TRM

# %%
data = pd.read_csv('BASES\\1.1.2.TCM_Para rango de fechas dado.csv')

# %%
data.head()
# Out:
#     Año Fecha (dd/mm/aaaa)      TRM  Día del mes      Mes  Id Mes
# 0  2024         2024-10-31  4413,46           31  Octubre      10
# 1  2024         2024-10-30  4367,39           30  Octubre      10
# 2  2024         2024-10-29   4342,9           29  Octubre      10
# 3  2024         2024-10-28  4316,73           28  Octubre      10
# 4  2024         2024-10-27  4316,73           27  Octubre      10

# %%
data['Fecha (dd/mm/aaaa)'] = pd.to_datetime(data['Fecha (dd/mm/aaaa)'], format='%Y-%m-%d')

# %%
data['TRM'] = data['TRM'].str.replace(',', '.').astype(float)

# %%
data.head()
# Out:
#     Año Fecha (dd/mm/aaaa)      TRM  Día del mes      Mes  Id Mes
# 0  2024         2024-10-31  4413.46           31  Octubre      10
# 1  2024         2024-10-30  4367.39           30  Octubre      10
# 2  2024         2024-10-29  4342.90           29  Octubre      10
# 3  2024         2024-10-28  4316.73           28  Octubre      10
# 4  2024         2024-10-27  4316.73           27  Octubre      10

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1097 entries, 0 to 1096
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Año                 1097 non-null   int64
#  1   Fecha (dd/mm/aaaa)  1097 non-null   datetime64[ns]
#  2   TRM                 1097 non-null   float64
#  3   Día del mes         1097 non-null   int64
#  4   Mes                 1097 non-null   object
#  5   Id Mes              1097 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(1)
# memory usage: 51.6+ KB

# %%
data = data.drop(columns=['Año', 'Día del mes', 'Mes', 'Id Mes'])

# %%
data.set_index('Fecha (dd/mm/aaaa)', inplace=True)

# %%
data
# Out:
#                         TRM
# Fecha (dd/mm/aaaa)
# 2024-10-31          4413.46
# 2024-10-30          4367.39
# 2024-10-29          4342.90
# 2024-10-28          4316.73
# 2024-10-27          4316.73
# ...                     ...
# 2021-11-04          3837.84
# 2021-11-03          3778.69
# 2021-11-02          3784.44
# 2021-11-01          3784.44
# 2021-10-31          3784.44
#
# [1097 rows x 1 columns]

# %% [markdown]
# ## Preprocesamiento de Datos

# %%
plt.figure(figsize=(10, 5))
plt.plot(data.index, data['TRM'], color='blue', label='TRM')
plt.title('Tasa Representativa del Mercado (TRM) - Colombia')
plt.xlabel('Fecha')
plt.ylabel('Valor')
plt.legend()
plt.show()

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
data['TRM_scaled'] = scaler.fit_transform(data[['TRM']])

# %%
def create_sequences(data, seq_length=60):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length])
    return np.array(X), np.array(y)

# %%
train_size = int(len(data) * 0.8)
train_data, test_data = data['TRM_scaled'].values[:train_size], data['TRM_scaled'].values[train_size:]

# %%
seq_length = 60
X_train, y_train = create_sequences(train_data, seq_length)
X_test, y_test = create_sequences(test_data, seq_length)

# %%
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %%
model = Sequential([
    LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], 1)),
    LSTM(50, return_sequences=False),
    Dense(25),
    Dense(1)
])
# Out:
# C:\Users\juano\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_8 (LSTM)                   │ (None, 60, 50)         │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_9 (LSTM)                   │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 25)             │         1,275 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │            26 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 31,901 (124.61 KB)
#  Trainable params: 31,901 (124.61 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=50,
    batch_size=32,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - loss: 0.0754 - val_loss: 0.0057
# Epoch 2/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0061 - val_loss: 0.0011
# Epoch 3/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0039 - val_loss: 9.8387e-04
# Epoch 4/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0038 - val_loss: 9.5846e-04
# Epoch 5/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0034 - val_loss: 8.9695e-04
# Epoch 6/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0033 - val_loss: 8.3219e-04
# Epoch 7/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0032 - val_loss: 8.9738e-04
# Epoch 8/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0027 - val_loss: 0.0011
# Epoch 9/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0030 - val_loss: 8.2894e-04
# Epoch 10/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0028 - val_loss: 7.5994e-04
# Epoch 11/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0026 - val_loss: 9.7390e-04
# Epoch 12/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0027 - val_loss: 8.5930e-04
# Epoch 13/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0025 - val_loss: 8.2790e-04
# Epoch 14/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0025 - val_loss: 9.3030e-04
# Epoch 15/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0025 - val_loss: 7.5189e-04
# Epoch 16/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0023 - val_loss: 6.8924e-04
# Epoch 17/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0023 - val_loss: 9.3654e-04
# Epoch 18/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0026 - val_loss: 6.9901e-04
# Epoch 19/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0025 - val_loss: 6.8027e-04
# Epoch 20/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0023 - val_loss: 6.4454e-04
# Epoch 21/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0021 - val_loss: 6.3813e-04
# Epoch 22/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0019 - val_loss: 6.3719e-04
# Epoch 23/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0021 - val_loss: 6.2677e-04
# Epoch 24/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0018 - val_loss: 6.1858e-04
# Epoch 25/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0017 - val_loss: 5.8076e-04
# Epoch 26/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0018 - val_loss: 5.6490e-04
# Epoch 27/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0014 - val_loss: 8.2197e-04
# Epoch 28/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0019 - val_loss: 5.7585e-04
# Epoch 29/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0015 - val_loss: 5.3924e-04
# Epoch 30/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0013 - val_loss: 5.0523e-04
# Epoch 31/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0013 - val_loss: 6.0505e-04
# Epoch 32/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0012 - val_loss: 4.8251e-04
# Epoch 33/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0011 - val_loss: 4.6169e-04
# Epoch 34/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0012 - val_loss: 4.6843e-04
# Epoch 35/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0011 - val_loss: 4.5485e-04
# Epoch 36/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.6985e-04 - val_loss: 4.4654e-04
# Epoch 37/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 9.4849e-04 - val_loss: 4.3085e-04
# Epoch 38/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 8.5827e-04 - val_loss: 4.1011e-04
# Epoch 39/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 8.6321e-04 - val_loss: 4.3525e-04
# Epoch 40/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 8.4479e-04 - val_loss: 4.4815e-04
# Epoch 41/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 8.9973e-04 - val_loss: 4.0517e-04
# Epoch 42/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 7.2787e-04 - val_loss: 3.9749e-04
# Epoch 43/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 7.5575e-04 - val_loss: 4.2192e-04
# Epoch 44/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 7.5584e-04 - val_loss: 4.1782e-04
# Epoch 45/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.5025e-04 - val_loss: 3.8126e-04
# Epoch 46/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 8.4591e-04 - val_loss: 3.8284e-04
# Epoch 47/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 8.8564e-04 - val_loss: 4.2162e-04
# Epoch 48/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.4948e-04 - val_loss: 3.8912e-04
# Epoch 49/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 7.2121e-04 - val_loss: 3.6699e-04
# Epoch 50/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 8.7073e-04 - val_loss: 5.0134e-04

# %%
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
y_test_rescaled = scaler.inverse_transform(y_test.reshape(-1, 1))

# %%
mae = np.mean(np.abs(predictions - y_test_rescaled))
mse = np.mean((predictions - y_test_rescaled) ** 2)
rmse = np.sqrt(mse)

print(f'Mean Absolute Error (MAE): {mae:.2f}')
print(f'Mean Squared Error (MSE): {mse:.2f}')
print(f'Root Mean Squared Error (RMSE): {rmse:.2f}')
# Out:
# Mean Absolute Error (MAE): 17.94
# Mean Squared Error (MSE): 673.07
# Root Mean Squared Error (RMSE): 25.94

# %%
r2 = r2_score(y_test_rescaled, predictions)
r2_percentage = r2 * 100

print(f'Coefficient of Determination (R²): {r2:.4f}')
print(f'Coefficient of Determination (R²) as Percentage: {r2_percentage:.2f}%')
# Out:
# Coefficient of Determination (R²): 0.9077
# Coefficient of Determination (R²) as Percentage: 90.77%

# %%
plt.figure(figsize=(10, 5))
plt.plot(data.index[-len(y_test):], y_test_rescaled, color='blue', label='Valor Real')
plt.plot(data.index[-len(predictions):], predictions, color='red', label='Predicciones')
plt.title('Predicción de la TRM - Últimos 3 Meses')
plt.xlabel('Fecha')
plt.ylabel('TRM')
plt.legend()
plt.show()

# %%
model.save('modelo_trm.h5')
print("Modelo guardado como 'modelo_trm.h5'")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Modelo guardado como 'modelo_trm.h5'
